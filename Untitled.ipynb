# %%
import pandas as pd

# %%
file1 = "static/data/sales_by_model.csv"
file1_df = pd.read_csv(file1)

# %%
file1_df
# Out:
#                              Vehicle  Type      2011      2012      2013  \
# 0                         Chevy Volt  PHEV    7,671    23,461    23,094
# 1                        Nissan Leaf    EV    9,674     9,819    22,610
# 2                           Smart ED    EV      342       139       923
# 3                    Mitsubishi I EV    EV       76       588     1,029
# 4                       BMW Active E    EV      -         673       -
# 5                         Prius PHEV  PHEV      -      12,749    12,088
# 6                      Ford Focus EV    EV      -         683     1,738
# 7                       Honda Fit EV    EV      -          93       569
# 8                      Tesla Model S    EV      -       2,400    19,400
# 9                     Toyota RAV4 EV    EV      -         192     1,005
# 10                 Ford C-Max Energi  PHEV      -       2,374     7,154
# 11                      Honda Accord  PHEV      -         -         526
# ...
