# %%
import pandas as pd

# %%
file1 = "static/data/sales_by_model.csv"
file1_df = pd.read_csv(file1)

# %%
file1_df
# Out:
#                              Vehicle  Type    2011    2012    2013     2014  \
# 0                         Chevy Volt  PHEV   7,671  23,461  23,094   18,805
# 1                        Nissan Leaf    EV   9,674   9,819  22,610   30,200
# 2                           Smart ED    EV     342     139     923    2,594
# 3                    Mitsubishi I EV    EV      76     588   1,029      196
# 4                       BMW Active E    EV       0     673       0        0
# 5                         Prius PHEV  PHEV       0  12,749  12,088   13,264
# 6                      Ford Focus EV    EV       0     683   1,738    1,964
# 7                       Honda Fit EV    EV       0      93     569      407
# 8                      Tesla Model S    EV       0   2,400  19,400   16,750
# 9                     Toyota RAV4 EV    EV       0     192   1,005    1,184
# 10                 Ford C-Max Energi  PHEV       0   2,374   7,154    8,433
# ...

# %%
file1_df["2011"] =  file1_df.Total.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d94cde7fa27b> in <module>
# ----> 1 file1_df["2011"] =  file1_df.Total.astype(float)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
